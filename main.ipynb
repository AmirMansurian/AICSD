# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/KD/
# !ls
# Out:
# /content/drive/MyDrive/KD
# dataloaders   mypath.py    README.md  train_voc.sh		  VOCdevkit
# distiller.py  pretrained   run	      train_with_distillation.py
# modeling      __pycache__  train.py   utils

# %%
# !python train.py --backbone mobilenet --lr 0.007 --epochs 50 --batch-size 16 --checkname deeplab-resnet --eval-interval 1 --dataset pascal
# Out:
# Namespace(backbone='mobilenet', base_size=513, batch_size=16, checkname='deeplab-resnet', crop_size=513, cuda=True, dataset='pascal', epochs=50, eval_interval=1, freeze_bn=False, ft=False, gpu_ids=[0], loss_type='ce', lr=0.007, lr_scheduler='poly', momentum=0.9, nesterov=False, no_cuda=False, no_val=False, out_stride=16, resume=None, seed=1, start_epoch=0, sync_bn=False, test_batch_size=16, use_balanced_weights=False, use_sbd=False, weight_decay=0.0005, workers=4)
# Number of images in train: 1464
# Number of images in val: 1449
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...
